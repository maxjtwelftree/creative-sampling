# %%
import pandas as pd
from compute_elo import Elo
from ranker import Ranker
from datasets import load_dataset

# %%
df = pd.DataFrame(
    {
    'id': ['a', 'b', 'c', 'd'],
    'rating': [1000, 1000, 1000, 1000]
    }
)

# %%
df
# Out:
#   id  rating
# 0  a    1000
# 1  b    1000
# 2  c    1000
# 3  d    1000

# %%
df['rating'] = df['rating'].astype(float)

# %%
# df[df["id"] == "a"]["rating"] = 3

# %%
df.loc[df["id"] == 'a', "rating"]
# Out:
# 0    1000.0
# Name: rating, dtype: float64

# %%
df
# Out:
#   id  rating
# 0  a  1000.0
# 1  b  1000.0
# 2  c  1000.0
# 3  d  1000.0

# %%
test = Elo()

# %%
test.rank(100, 500, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test.rank(100, 500, 0)
#
# NameError: name 'test' is not defined

# %%
test_2 = Ranker(test, df)

# %%
test_2.select()
# Out:
# [1, 0]

# %%
test_2.df
# Out:
#   id  rating
# 0  a  1000.0
# 1  b  1000.0
# 2  c  1000.0
# 3  d  1000.0

# %%
# indices = test_2.select()

# %%
# indices

# %%
# test_2.update(indices, 0)

# %%
test_2.df
# Out:
#   id  rating
# 0  a  1000.0
# 1  b  1000.0
# 2  c  1000.0
# 3  d  1000.0

# %%
def f():
    test_2.run_update()
    print(test_2.df)

# %%
f()
# Out:
# p1 1051.3845041606157 p2 994.5058368150559
# updates
# [1064.788297002802, 981.1020439728696]
#   id       rating
# 0  a   981.102044
# 1  b  1064.788297
# 2  c   954.853052
# 3  d   999.256607

# %%
test_2.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      object
#  1   rating  4 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
dataset = load_dataset("sander-wood/irishman")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['abc notation', 'control code'],
#         num_rows: 214122
#     })
#     validation: Dataset({
#         features: ['abc notation', 'control code'],
#         num_rows: 2162
#     })
# })

# %%
dataset["train"]
# Out:
# Dataset({
#     features: ['abc notation', 'control code'],
#     num_rows: 214122
# })

# %%
dataset["train"]["abc notation"]
# Out:
# ['X:1\nL:1/8\nM:4/4\nK:Emin\n|: E2 EF E2 EF | DEFG AFDF | E2 EF E2 B2 |1 efe^d e2 e2 :|2 efe^d e3 B |: e2 ef g2 fe | \n defg afdf |1 e2 ef g2 fe | efe^d e3 B :|2 g2 bg f2 af | efe^d e2 e2 ||',
#  'X:2\nL:1/4\nM:3/4\nK:C\n G | E3/2 E/ E | G2 G | c2 c | G2 G | G2 c/>c/ | B2 d | d3 | c2 G | e2 e | e d c | B2 A | A2 A | \n B2 B | d2 d | d3 | c2 G | e2 e | e d c | B2 A | A2 A | B2 B | d2 d | d3 | c2 |]',
#  'X:3\nL:1/8\nQ:1/4=100\nM:2/4\nK:Emin\n E | ABcA | E2 EF | G2 GB | (d/c/B/A/) GB | AGAB | E2 E=f | edcB | A2 A :: B | c>Bce | d>cde | \n c>Bce | (d/c/B/A/) GB | c>Bce | dcd=f | edcB | A2 A :|',
#  'X:4\nL:1/8\nM:6/8\nK:A\n|: EFG ||"A" A2 A A2 A |"F#m" A2 A A2 A |"B7" B2 A G2 F |"E7" E6 |"A" A2 A A3 |"D" A2 A A3 | \n"A" c2 A"E7" B2 G |"^A fine" A3 :|"A7" A2 A ||"D" F6- | F3 A2 A |"A" E6- | E3 A2 G | \n"B7" F2 F F2 F | F2 F G2 A |"E7" B3- B3- |"^d.C" B3 |]',
# ...

# %%
df = pd.DataFrame(dataset["train"])

# %%
df = df.reset_index()

# %%
df
# Out:
#          index                                       abc notation  \
# 0            0  X:1\nL:1/8\nM:4/4\nK:Emin\n|: E2 EF E2 EF | DE...
# 1            1  X:2\nL:1/4\nM:3/4\nK:C\n G | E3/2 E/ E | G2 G ...
# 2            2  X:3\nL:1/8\nQ:1/4=100\nM:2/4\nK:Emin\n E | ABc...
# 3            3  X:4\nL:1/8\nM:6/8\nK:A\n|: EFG ||"A" A2 A A2 A...
# 4            4  X:5\nL:1/8\nM:6/8\nK:G\n (G/A/B).D D>ED | DcB ...
# ...        ...                                                ...
# 214117  214117  X:214118\nL:1/8\nM:2/4\nK:F\n C | FFFF | AFFF ...
# 214118  214118  X:214119\nL:1/8\nM:4/4\nK:G\n (g/>a/) | (b<g) ...
# 214119  214119  X:214120\nL:1/8\nM:3/4\nK:A\n|: [Eca]3 c/a/ B3...
# 214120  214120  X:214121\nL:1/8\nQ:1/4=110\nM:2/4\nK:D\n"_See ...
# 214121  214121  X:214122\nL:1/8\nQ:1/8=140\nM:3/4\nK:F\n"^slow...
#
#                                              control code
# 0                                    S:2\nB:5\nE:5\nB:6\n
# ...

# %%
# !pwd
# Out:
# /home/alik/Documents/Projects/aiml_music/ranker

# %%
df.to_parquet("irishman.parquet")

# %%
df["rating"] = 1000

# %%
df = df.rename(
    columns={
        "index": "id"
    }
)

# %%
df.reset_index()[df.reset_index()["index"] == 2]
# Out:
#    index                                       abc notation  \
# 2      2  X:3\nL:1/8\nQ:1/4=100\nM:2/4\nK:Emin\n E | ABc...
#
#            control code
# 2  S:2\nB:9\nE:7\nB:9\n

# %%
df.iloc[0:100]
# Out:
#     index                                       abc notation  \
# 0       0  X:1\nL:1/8\nM:4/4\nK:Emin\n|: E2 EF E2 EF | DE...
# 1       1  X:2\nL:1/4\nM:3/4\nK:C\n G | E3/2 E/ E | G2 G ...
# 2       2  X:3\nL:1/8\nQ:1/4=100\nM:2/4\nK:Emin\n E | ABc...
# 3       3  X:4\nL:1/8\nM:6/8\nK:A\n|: EFG ||"A" A2 A A2 A...
# 4       4  X:5\nL:1/8\nM:6/8\nK:G\n (G/A/B).D D>ED | DcB ...
# ..    ...                                                ...
# 95     95  X:96\nL:1/8\nM:2/2\nK:G\n D | G2 BG dGBG | G2 ...
# 96     96  X:97\nL:1/8\nM:6/8\nK:A\n|: cAA eAA | cAA e2 c...
# 97     97  X:98\nL:1/8\nM:4/4\nK:D\n|: D2 d>A F2 A>F | G2...
# 98     98  X:99\nL:1/8\nM:6/8\nK:D\n A |: d3 AFD | E2 F G...
# 99     99  X:100\nL:1/8\nM:3/4\nK:G\n d2 | g3 a b2 | g4 f...
#
#                                          control code  rating
# 0                                S:2\nB:5\nE:5\nB:6\n    1000
# 1                                         S:1\nB:25\n    1000
# ...

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
!"jupyter nbextension enable --py widgetsnbextension"
# Out:
# /bin/bash: line 1: jupyter nbextension enable --py widgetsnbextension: command not found
